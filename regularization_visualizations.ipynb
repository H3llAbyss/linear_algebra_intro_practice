# %% [markdown]
# # Regularization Regression Visualizations
# This notebook reuses the code from `regularization.py` to train and visualize regression models.

# %%
import numpy as np
from regularization import *

# %%
X_train, X_test, y_train, y_test = get_regression_data()

# %%
lin_model = linear_regression(X_train, y_train)
ridge_model = ridge_regression(X_train, y_train)
lasso_model = lasso_regression(X_train, y_train)

# %%
import matplotlib.pyplot as plt

models = {
    "Linear Regression": lin_model,
    "Ridge Regression": ridge_model,
    "Lasso Regression": lasso_model
}

for name, model in models.items():
    y_pred = model.predict(X_test)

    plt.figure()
    plt.scatter(y_test, y_pred)
    plt.xlabel("True Values")
    plt.ylabel("Predictions")
    plt.title(name)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()])
    plt.show()

# %%
plt.figure(figsize=(8, 6))

for name, model in models.items():
    y_pred = model.predict(X_test)
    plt.scatter(y_test, y_pred, alpha=0.6, label=name)

min_val = min(y_test.min(), *(model.predict(X_test).min() for model in models.values()))
max_val = max(y_test.max(), *(model.predict(X_test).max() for model in models.values()))
plt.plot([min_val, max_val], [min_val, max_val], "k--", linewidth=2, label="Ideal")

plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Regression Model Comparison (Diabetes Dataset)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

for name, model in models.items():
    y_pred = model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"{name}:")
    print(f"  MSE = {mse:.2f}")
    print(f"  MAE = {mae:.2f}")
    print(f"  R²  = {r2:.4f}")
    print("-" * 30)
# Out:
# Linear Regression:
#   MSE = 2951.89
#   MAE = 45.35
#   R²  = 0.5047
# ------------------------------
# Ridge Regression:
#   MSE = 2936.43
#   MAE = 45.49
#   R²  = 0.5073
# ------------------------------
# Lasso Regression:
#   MSE = 2907.42
#   MAE = 45.37
#   R²  = 0.5122
# ------------------------------
